# %%
import pandas as pd
data={'Day':['1/1/2024','1/2/2024','1/3/2024','1/4/2024','1/5/2024','1/6/2024','1/7/2024']
      ,'Temperature':[20,32,33,35,30,33,34],'Wind Speed':[10,20,30,40,50,60,70]
      ,'Event':['Sunny','Rainy','Snow','Rainy','Sunny','Snow','Sunny'],
      }
df=pd.DataFrame(data)
df
# Out:
#         Day  Temperature  Wind Speed  Event
# 0  1/1/2024           20          10  Sunny
# 1  1/2/2024           32          20  Rainy
# 2  1/3/2024           33          30   Snow
# 3  1/4/2024           35          40  Rainy
# 4  1/5/2024           30          50  Sunny
# 5  1/6/2024           33          60   Snow
# 6  1/7/2024           34          70  Sunny

# %%
df.columns
# Out:
# Index(['Day', 'Temperature', 'Wind Speed', 'Event'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
type(df['Wind Speed'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# Day            object
# Temperature     int64
# Wind Speed      int64
# Event          object
# dtype: object

# %%
newdf=df.copy()
newdf
# Out:
#         Day  Temperature  Wind Speed  Event
# 0  1/1/2024           20          10  Sunny
# 1  1/2/2024           32          20  Rainy
# 2  1/3/2024           33          30   Snow
# 3  1/4/2024           35          40  Rainy
# 4  1/5/2024           30          50  Sunny
# 5  1/6/2024           33          60   Snow
# 6  1/7/2024           34          70  Sunny

# %%
df.T
# Out:
#                     0         1         2         3         4         5  \
# Day          1/1/2024  1/2/2024  1/3/2024  1/4/2024  1/5/2024  1/6/2024
# Temperature        20        32        33        35        30        33
# Wind Speed         10        20        30        40        50        60
# Event           Sunny     Rainy      Snow     Rainy     Sunny      Snow
#
#                     6
# Day          1/7/2024
# Temperature        34
# Wind Speed         70
# Event           Sunny

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#         Day  Temperature  Wind Speed  Event
# 6  1/7/2024           34          70  Sunny
# 5  1/6/2024           33          60   Snow
# 4  1/5/2024           30          50  Sunny
# 3  1/4/2024           35          40  Rainy
# 2  1/3/2024           33          30   Snow
# 1  1/2/2024           32          20  Rainy
# 0  1/1/2024           20          10  Sunny

# %%
df.sort_values('Temperature',axis=0,ascending=False)
# Out:
#         Day  Temperature  Wind Speed  Event
# 3  1/4/2024           35          40  Rainy
# 6  1/7/2024           34          70  Sunny
# 2  1/3/2024           33          30   Snow
# 5  1/6/2024           33          60   Snow
# 1  1/2/2024           32          20  Rainy
# 4  1/5/2024           30          50  Sunny
# 0  1/1/2024           20          10  Sunny

# %%
df
# Out:
#         Day  Temperature  Wind Speed  Event
# 0  1/1/2024           20          10  Sunny
# 1  1/2/2024           32          20  Rainy
# 2  1/3/2024           33          30   Snow
# 3  1/4/2024           35          40  Rainy
# 4  1/5/2024           30          50  Sunny
# 5  1/6/2024           33          60   Snow
# 6  1/7/2024           34          70  Sunny

# %%
df.loc[0,'Temperature']=20
df.loc[4,'Event']='Rainy'
df
# Out:
#         Day  Temperature  Wind Speed  Event
# 0  1/1/2024           20          10  Sunny
# 1  1/2/2024           32          20  Rainy
# 2  1/3/2024           33          30   Snow
# 3  1/4/2024           35          40  Rainy
# 4  1/5/2024           30          50  Rainy
# 5  1/6/2024           33          60   Snow
# 6  1/7/2024           34          70  Sunny

# %%
df.loc[(df['Temperature']<=30) & (df['Wind Speed']>=20)]
# Out:
#         Day  Temperature  Wind Speed  Event
# 4  1/5/2024           30          50  Rainy

# %%
df
# Out:
#         Day  Temperature  Wind Speed  Event
# 0  1/1/2024           20          10  Sunny
# 1  1/2/2024           32          20  Rainy
# 2  1/3/2024           33          30   Snow
# 3  1/4/2024           35          40  Rainy
# 4  1/5/2024           30          50  Rainy
# 5  1/6/2024           33          60   Snow
# 6  1/7/2024           34          70  Sunny

# %%
df.loc[1,'Event']
# Out:
# 'Rainy'

# %%
df.iloc[[0,1],[1,3]]
# Out:
#    Temperature  Event
# 0           20  Sunny
# 1           32  Rainy

# %%
df
# Out:
#         Day  Temperature  Wind Speed  Event
# 0  1/1/2024           20          10  Sunny
# 1  1/2/2024           32          20  Rainy
# 2  1/3/2024           33          30   Snow
# 3  1/4/2024           35          40  Rainy
# 4  1/5/2024           30          50  Rainy
# 5  1/6/2024           33          60   Snow
# 6  1/7/2024           34          70  Sunny

# %%
df.drop([2,4],inplace=True)
df
# Out:
#         Day  Temperature  Wind Speed  Event
# 0  1/1/2024           20          10  Sunny
# 1  1/2/2024           32          20  Rainy
# 3  1/4/2024           35          40  Rainy
# 5  1/6/2024           33          60   Snow
# 6  1/7/2024           34          70  Sunny

# %%
df.drop(['Wind Speed'],axis=1)
# Out:
#         Day  Temperature  Event
# 0  1/1/2024           20  Sunny
# 1  1/2/2024           32  Rainy
# 3  1/4/2024           35  Rainy
# 5  1/6/2024           33   Snow
# 6  1/7/2024           34  Sunny

# %%
df.reset_index(inplace=True)
df
# Out:
#    index       Day  Temperature  Wind Speed  Event
# 0      0  1/1/2024           20          10  Sunny
# 1      1  1/2/2024           32          20  Rainy
# 2      3  1/4/2024           35          40  Rainy
# 3      5  1/6/2024           33          60   Snow
# 4      6  1/7/2024           34          70  Sunny

# %%
df['Humidity']=[16,18,19,20,21]
df
# Out:
#    index       Day  Temperature  Wind Speed  Event  Humidity
# 0      0  1/1/2024           20          10  Sunny        16
# 1      1  1/2/2024           32          20  Rainy        18
# 2      3  1/4/2024           35          40  Rainy        19
# 3      5  1/6/2024           33          60   Snow        20
# 4      6  1/7/2024           34          70  Sunny        21

# %%
df.notnull()
# Out:
#    index   Day  Temperature  Wind Speed  Event  Humidity
# 0   True  True         True        True   True      True
# 1   True  True         True        True   True      True
# 2   True  True         True        True   True      True
# 3   True  True         True        True   True      True
# 4   True  True         True        True   True      True

# %%
df.isnull().sum()
# Out:
# index          0
# Day            0
# Temperature    0
# Wind Speed     0
# Event          0
# Humidity       0
# dtype: int64

# %%
d1=[
    ('shiv',80),
     ('ram',70)
  ]
df1=pd.DataFrame(d1,columns=['Name','Marks'])
df1
# Out:
#    Name  Marks
# 0  shiv     80
# 1   ram     70

# %%
data2=[
    {'name':'sanet','marks':55},
     {'name':'yug','marks':65}
    ]
df2=pd.DataFrame(data2)
df2
# Out:
#     name  marks
# 0  sanet     55
# 1    yug     65

# %%
df3=pd.concat([df2,df1],ignore_index=True)
df3
# Out:
#     name  marks  Name  Marks
# 0  sanet   55.0   NaN    NaN
# 1    yug   65.0   NaN    NaN
# 2    NaN    NaN  shiv   80.0
# 3    NaN    NaN   ram   70.0

# %%
df4=pd.concat([df2,df1],axis=1)
df4
# Out:
#     name  marks  Name  Marks
# 0  sanet     55  shiv     80
# 1    yug     65   ram     70

# %% [markdown]
# APPEND

# %%
df5=pd.concat([df3,df1],ignore_index=True)
df5
# Out:
#     name  marks  Name  Marks
# 0  sanet   55.0   NaN    NaN
# 1    yug   65.0   NaN    NaN
# 2    NaN    NaN  shiv   80.0
# 3    NaN    NaN   ram   70.0
# 4    NaN    NaN  shiv   80.0
# 5    NaN    NaN   ram   70.0

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2 non-null      object
#  1   marks   2 non-null      float64
#  2   Name    4 non-null      object
#  3   Marks   4 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 320.0+ bytes
